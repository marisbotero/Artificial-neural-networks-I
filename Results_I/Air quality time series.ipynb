# %%
import numpy as np
import pandas as pd
from pandas import Series
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import TimeGrouper
from pandas.tools.plotting import lag_plot

# %matplotlib inline

# %%
pm25 = pd.read_csv('Desktop/TFM/dataset-pm25.csv',index_col='fecha')

# %%
pm25.head()
# Out:
#                      pm25
# fecha
# 2012-07-06 11:00:00    29
# 2012-07-06 12:00:00    21
# 2012-07-06 13:00:00    20
# 2012-07-06 14:00:00    24
# 2012-07-06 15:00:00    13

# %%
pm25.index = pd.to_datetime(pm25.index)

# %%
pm25.plot()

# %%
from pandas.tools.plotting import autocorrelation_plot
autocorrelation_plot(pm25)
# Out:
# C:\Users\W\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.

# %%
pm25.plot(kind='kde')

# %%
pm25.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002198014EB00>]], dtype=object)

# %%
pm25.plot(style='k.')
pyplot.show()

# %%
lag_plot(pm25)
pyplot.show()
# Out:
# C:\Users\W\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.lag_plot' is deprecated, import 'pandas.plotting.lag_plot' instead.
#   """Entry point for launching an IPython kernel.
